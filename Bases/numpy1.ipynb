# %%
import numpy as np

# %%
# Out:
#   File "/tmp/ipython-input-2197221783.py", line 2
#     a = np.array([1, 2, 3])
#     ^
# IndentationError: unexpected indent

# %%
 print("\n=== TABLEAUX SPECIAUX ===")
